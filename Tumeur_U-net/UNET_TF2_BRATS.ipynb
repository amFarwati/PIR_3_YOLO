# %% [markdown]
# # <span style="color:brown"> **UNET Segmentation TRAINING on BRATS**
# ### *Keras / Tensorflow<span style="color:brown">  2*
#
# *thomas.grenier@creatis.insa-lyon.fr*

# %% [markdown]
# Here, we train a UNet network.
# We first need to go deeper in this architecture.
#
# ### <span style="color:brown"> **UNet**
# This network is fully convolutional. It uses skip connections from the encoder side to the decoder side to preserve scale information.
#
# This basic architecture can be changed in order to best perform on your data.
# In the following figure, the UNet is a 4 stages (or levels) UNet with 32 neurons on the first layer. These two features are the most significant for this architecture.
#
# The encoder side consists of 2 convolution layers (convolution + activation + batch normalization) at each level.
# Each level has twice more neurons than the previous one.
# To jump from on level to the next one, a max pooling is performed which reduces the spatial size by 4.
#
# The decoder processes symmetrically.
# At each level, the features coming from the encoder level aside is concatenated to the features coming from the lower decoder level.
# Then, as for the encoder, decoder levels consist of 2 convolution layers.
# To adapt the spatial size from one stage to thee next one, an upsampling is performed.
# This upsampling can be done by interpolation (https://keras.io/api/layers/reshaping_layers/up_sampling2d/) or by transposed convolution (https://keras.io/api/layers/convolution_layers/convolution2d_transpose/) that someway learnt how to interpolate.
#
# To produce the segmentation, all feature are first sumup to a *n* features map, where *n* is the number of classes, by *n* 1x1 convolution layer.
# Then a *arg max* is done to produce the segmentation in the multi-classe case.
# For binary segmentation, a simple threshold does the job.
#
# <img src="figures/UNet.png" alt="UNet" style="width: 70%;"/>
#
# In this UNet implementation, many parameters can be modified:
# - The number of levels
# - The amount of feature at first level.
# - Batch normalization can be activated or not
# - Dropout amount (0.0 means no dropout)
# - The upsampling strategy
# - Activation functions
# - Number of classes
#
# Then, many hyper-parameters can be tuned for training.
#
# In this notebook, you will train a UNet.

# %% [markdown]
# ## <span style="color:brown"> **1- System and basic imports**

# %%
import glob
import os
import sys
from datetime import datetime
# !pip install tqdm
from tqdm import tqdm 

import numpy as np

# !pip install SimpleITK
import SimpleITK as sitk

# !pip install scikit-learn
import sklearn

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,15)

import cv2
    
#prevent unwanted warning 
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
# Out:
# Requirement already satisfied: tqdm in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (4.65.0)
# Requirement already satisfied: SimpleITK in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: scikit-learn in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/saturncloud/envs/saturn/lib/python3.9/site-packages (from scikit-learn) (1.21.6)

# %% [markdown]
# ## <span style="color:brown"> **2- Important parameters**

# %%
IMG_SIZE =  224  # input image size

VALIDATION_RATIO = 0.1

JUPYTER_DISPLAY_ON = True # True or False used for displaying (or not) images

# %% [markdown]
# ### Parameters to tune

# %%
# Network architecture related values 
NBLAYERS_UNET = 5      # <- number of levels [5]
NBFILTERS_L1_UNET = 32 # <- number of neurons for the first level [32]
DROPOUT_RATE = 0.1     # 0.0  to 1.0 [0.1]
KERNEL_SIZE = (3,3)    # (3,3)  (5,5) 
BATCHNORM_ON = True    # True or False [False]

CNN_ACTIVATION = 'relu' # relu, elu, selu, LeakyReLU, ...

# Training parameters
NBEPOCHS = 200          # Nb of Epoch  [60]
BATCH_SIZE = 16       # Number of sample in each batch (4 to 64) [16]
NBSTEPS_PER_EPOCH = 50  # nb of batches per epoch (1  to ...)  [50] (used for data augmentation)
NBPATIENCE_EPOCHS = 30  # nb of epoch after a minimum detection before stopping (early stop) [30]

# %% [markdown]
# ### Name of the model file

# %%
model_path = './trained_model/'
model_name = 'Unet_1i_f' + str(NBFILTERS_L1_UNET) + '_l'+ str(NBLAYERS_UNET) +  '_k'+ str(KERNEL_SIZE[0]) + '_do' + str(DROPOUT_RATE) +'_act'+CNN_ACTIVATION + '_b' + str(BATCH_SIZE) +'_Std'
if BATCHNORM_ON == True:
    model_name = model_name + '_BN'
model_filename = model_path + model_name + '_input'+ str(IMG_SIZE) +'.h5'
print(" -> model_study : ", model_name)
print(" -> model_filename : ", model_filename)
# Out:
#  -> model_study :  Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN
#  -> model_filename :  ./trained_model/Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN_input224.h5

# %% [markdown]
# ## <span style="color:brown"> **3- Session launch**

# %%
import tensorflow as tf

print(tf.__version__)
print("Number of GPUs available : ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2.9.1
# Number of GPUs available :  1

# %% [markdown]
# ## <span style="color:brown"> **4- Load data**
#
# <span style="color:red">
#
# **Before running the next cell**, you must have :
#    1. downloaded the file ```dlss21_ho4_data.tar.gz```
#    2. unziped the downloaded file in the directory of this notebook.
#
# Data should be at ```./dlss21_ho4_data```
#
# ## <span style="color:brown"> 4.1- Load files and set names

# %%
train_Brats_flair=glob.glob("./Database/Train/*flair.png")
train_Brats_seg=glob.glob("./Database/Train/*seg.png")

test_Brats_flair= glob.glob("./Database/Test/*flair.png")
test_Brats_seg= glob.glob("./Database/Test/*seg.png")

logs_path = './logs/'
os.makedirs(logs_path, exist_ok=True)

train_Brats_flair.sort()
train_Brats_seg.sort()
test_Brats_flair.sort()
test_Brats_seg.sort()

nb_train = int( len(train_Brats_flair) * (1 - VALIDATION_RATIO) )

print( " training :  ", nb_train, nb_train )
print( " testing   :  ", len(test_Brats_flair), len(test_Brats_seg) )


print( " validation :  ", len(train_Brats_flair)-nb_train, len(train_Brats_seg)-nb_train )
# Out:
#  training :   1341 1341
#  testing   :   345 345
#  validation :   149 149

# %% [markdown]
# __The previous cell should output 717 as training images and 208 as testing images.
# If not, you must check where the data is.__

# %% [markdown]
# ## <span style="color:brown"> 4.2- Randomly permute the data

# %%
nb_display = 5
if JUPYTER_DISPLAY_ON == True:
    print( f" -> First {nb_display} train items ")
    [print(train_Brats_flair[i], train_Brats_seg[i]) for i in range(nb_display)]

    print( f" -> Last {nb_display} train items ")
    [print(train_Brats_flair[i], train_Brats_seg[i]) for i in range( len(train_Brats_seg)-nb_display, len(train_Brats_seg) )]

# permuation of inputs
permutation_train = np.random.permutation( len(train_Brats_seg))

# print("Permutation : ", permutation)
train_Brats_seg_rnd=[train_Brats_seg[i] for i in permutation_train]
train_Brats_flair_rnd=[train_Brats_flair[i] for i in permutation_train]


if JUPYTER_DISPLAY_ON == True:
    print( f" -> First PERMUTED {nb_display} train items ")
    [print(train_Brats_flair_rnd[i], train_Brats_seg_rnd[i]) for i in range(nb_display)]

    print( f" -> Last PERMUTED {nb_display} train items ")
    [print(train_Brats_flair_rnd[i], train_Brats_seg_rnd[i]) for i in range( len(train_Brats_seg)-nb_display, len(train_Brats_seg) )]

# Permuatation of test images : just to have more variability when displaying results... 
permutation_test = np.random.permutation( len(test_Brats_seg))
test_Brats_seg_rnd=[test_Brats_seg[i] for i in permutation_test]
test_Brats_flair_rnd=[test_Brats_flair[i] for i in permutation_test]
# Out:
#  -> First 5 train items
# ./Database/Train/001_1flair.png ./Database/Train/001_1seg.png
# ./Database/Train/001_2flair.png ./Database/Train/001_2seg.png
# ./Database/Train/001_3flair.png ./Database/Train/001_3seg.png
# ./Database/Train/001_4flair.png ./Database/Train/001_4seg.png
# ./Database/Train/001_5flair.png ./Database/Train/001_5seg.png
#  -> Last 5 train items
# ./Database/Train/300_1flair.png ./Database/Train/300_1seg.png
# ./Database/Train/300_2flair.png ./Database/Train/300_2seg.png
# ./Database/Train/300_3flair.png ./Database/Train/300_3seg.png
# ./Database/Train/300_4flair.png ./Database/Train/300_4seg.png
# ./Database/Train/300_5flair.png ./Database/Train/300_5seg.png
#  -> First PERMUTED 5 train items
# ./Database/Train/066_1flair.png ./Database/Train/066_1seg.png
# ./Database/Train/125_1flair.png ./Database/Train/125_1seg.png
# ./Database/Train/018_2flair.png ./Database/Train/018_2seg.png
# ./Database/Train/002_3flair.png ./Database/Train/002_3seg.png
# ./Database/Train/114_1flair.png ./Database/Train/114_1seg.png
#  -> Last PERMUTED 5 train items
# ./Database/Train/277_1flair.png ./Database/Train/277_1seg.png
# ./Database/Train/282_3flair.png ./Database/Train/282_3seg.png
# ./Database/Train/183_2flair.png ./Database/Train/183_2seg.png
# ./Database/Train/030_2flair.png ./Database/Train/030_2seg.png
# ./Database/Train/272_4flair.png ./Database/Train/272_4seg.png

# %% [markdown]
# ## <span style="color:brown"> 4.3- Functions to read, convert and resize the images and the masks

# %%
from keras_unet.utils import ReadImages, ReadMasks

# %% [markdown]
# ## <span style="color:brown"> 4.4 - Define sets : train, validation and test

# %%
# reading files
input_shape = (IMG_SIZE, IMG_SIZE, 1)

X_train = ReadImages(train_Brats_flair[:nb_train], size=(IMG_SIZE, IMG_SIZE))
y_train = ReadMasks(train_Brats_seg[:nb_train], size=(IMG_SIZE, IMG_SIZE))

X_val = ReadImages(train_Brats_flair_rnd[nb_train:], size=(IMG_SIZE, IMG_SIZE))
y_val = ReadMasks(train_Brats_seg_rnd[nb_train:], size=(IMG_SIZE, IMG_SIZE))

X_test= ReadImages(test_Brats_flair_rnd, size=(IMG_SIZE, IMG_SIZE))

y_test = ReadMasks(test_Brats_seg_rnd, size=(IMG_SIZE, IMG_SIZE))


input_shape = (IMG_SIZE, IMG_SIZE, 1)
# Out:
# 100%|██████████| 1341/1341 [00:01<00:00, 783.82it/s]
# 100%|██████████| 1341/1341 [00:00<00:00, 1725.56it/s]
# 100%|██████████| 149/149 [00:00<00:00, 1164.61it/s]
# 100%|██████████| 149/149 [00:00<00:00, 3789.37it/s]
# 100%|██████████| 345/345 [00:00<00:00, 792.89it/s]
# 100%|██████████| 345/345 [00:00<00:00, 1820.53it/s]

# %%
print(" Shape train: ", X_train.shape, y_train.shape)
print(" Shape valid: ", X_val.shape, y_val.shape)
print(" Shape test : ", X_test.shape, y_test.shape)

print(" Shape X_train and y_train : ", X_train.shape, y_train.shape)
print(" Shape X_val and y_val     : ", X_val.shape, y_val.shape)
print(" Shape X_test and y_test   : ", X_test.shape, y_test.shape)

print(" Type train: ", X_train.dtype, y_train.dtype)
print(" Type valid: ", X_val.dtype, y_val.dtype)
print(" Type test : ", X_test.dtype, y_test.dtype)
# Out:
#  Shape train:  (1341, 224, 224, 1) (1341, 224, 224, 5)
#  Shape valid:  (149, 224, 224, 1) (149, 224, 224, 5)
#  Shape test :  (345, 224, 224, 1) (345, 224, 224, 5)
#  Shape X_train and y_train :  (1341, 224, 224, 1) (1341, 224, 224, 5)
#  Shape X_val and y_val     :  (149, 224, 224, 1) (149, 224, 224, 5)
#  Shape X_test and y_test   :  (345, 224, 224, 1) (345, 224, 224, 5)
#  Type train:  float32 float32
#  Type valid:  float32 float32
#  Type test :  float32 float32

# %% [markdown]
# ## <span style="color:brown"> 4.4- Plot images
#
# ### 4.4.1 Display functions

# %%
from keras_unet.visualization import plot_overlay_segmentation, plot_compare_segmentation

# %% [markdown]
# ### 4.4.2 Plot images with overlay (mask over original)

# %%
if JUPYTER_DISPLAY_ON == True:
    [print(train_Brats_flair[i], train_Brats_seg[i]) for i in range(0,5)]
    plot_overlay_segmentation(X_train[0:5], y_train[0:5])
# Out:
# ./Database/Train/001_1flair.png ./Database/Train/001_1seg.png
# ./Database/Train/001_2flair.png ./Database/Train/001_2seg.png
# ./Database/Train/001_3flair.png ./Database/Train/001_3seg.png
# ./Database/Train/001_4flair.png ./Database/Train/001_4seg.png
# ./Database/Train/001_5flair.png ./Database/Train/001_5seg.png

# %% [markdown]
# ## <span style="color:brown"> 4.7- Prepare a generator for data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
#        featurewise_center=True,
#        featurewise_std_normalization=True,
        rotation_range=10,
        zoom_range=0.1,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False,
        vertical_flip=False,
        fill_mode='nearest',   # constant nearest, reflect or wrap
        validation_split=0)

class MyImageDataGenerator:
    def __init__(self, X, y, data_generator, batch_size):
        self.data_generator = data_generator
        self.batch_size=batch_size
        self.X = X
        self.y = y
        self.count = 0
        self.permutation = np.random.permutation(self.X.shape[0])
  
    def __iter__(self):
        self.count = 0
        self.permutation = np.random.permutation(self.X.shape[0])
        return self

    def __next__(self):
        if self.count > self.X.shape[0]//self.batch_size:
            self.count = 0
            self.permutation = np.random.permutation(self.X.shape[0])
 
        max_index = self.count*self.batch_size+self.batch_size # valeur index de fin
        if max_index > self.X.shape[0]-1:    # a t'on assez d'éléments ?
            max_index = self.X.shape[0]-1
        # permutation 
        X_rnd=np.asarray( [self.X[i] for i in self.permutation[self.count*self.batch_size:max_index]] )
        y_rnd=np.asarray( [self.y[i] for i in self.permutation[self.count*self.batch_size:max_index]] )
        
        for i in range(0,X_rnd.shape[0]):
            transf = self.data_generator.get_random_transform(img_shape = X_rnd.shape[1::] )   
            X_rnd[i,:,:,:] = self.data_generator.apply_transform( X_rnd[i,:,:,:], transform_parameters = transf)
            y_rnd[i,:,:,:] = self.data_generator.apply_transform( y_rnd[i,:,:,:], transform_parameters = transf)
        self.count += 1
        return X_rnd, y_rnd
 #       else:
  #          raise StopIteration

# %%
my_train_generator = MyImageDataGenerator(X_train, y_train, datagen, BATCH_SIZE)
my_train_iter = iter(my_train_generator)

# %%
X,y = next(my_train_iter)
print(X.shape)
print(y.shape)
# Out:
# (16, 224, 224, 1)
# (16, 224, 224, 5)

# %% [markdown]
# ### Example of an augmented data batch

# %%
if JUPYTER_DISPLAY_ON == True:
    plot_overlay_segmentation(X, y)

# %% [markdown]
# ## <span style="color:brown"> **5- Network and training**

# %% [markdown]
# ## <span style="color:brown"> 5.1- Initialize network

# %% [markdown]
# ### Import needed functions and reset the TF graph (safer, if you want to tune the model)

# %%
from keras_unet.models import custom_unet, xception_unet, lowfeaturedecoder_unet, attention_unet_smooth_network, attention_resunet_seg_decoder
from keras_unet.losses import dice_loss
from keras_unet.hausdorff_loss import Weighted_Hausdorff_loss

from tensorflow.keras import models
from tensorflow.keras import regularizers

# %% [markdown]
# ### Create model

# %%
print(" input_shape : ", input_shape)

if 'model' in locals(): 
    print("deleting model")
    del model
    
model = custom_unet(
    input_shape,
    use_batch_norm=BATCHNORM_ON,  
    num_classes=y_train[0].shape[-1],
    filters=NBFILTERS_L1_UNET, 
    dropout=DROPOUT_RATE,
    num_layers=NBLAYERS_UNET,
    kernel_size=KERNEL_SIZE,
    cnn_activation=CNN_ACTIVATION,
    output_activation='softmax',
    dropout_type='simple', # spatial or  simple
    kernel_initializer='he_normal',
    kernel_regularizer=None # regularizers.l1(0.001)  # =None   for no regularization
    )     


#model = lowfeaturedecoder_unet(
#    input_shape,
#    use_batch_norm=BATCHNORM_ON,  
#    num_classes=y_train[0].shape[-1],
#    filters=NBFILTERS_L1_UNET, 
#    dropout=DROPOUT_RATE,
#    num_layers=NBLAYERS_UNET,
#    kernel_size=KERNEL_SIZE,
#    cnn_activation=CNN_ACTIVATION,
#    output_activation='softmax',
#    kernel_initializer='he_normal',
#    kernel_regularizer=None # regularizers.l1(0.001)  # =None   for no regularization
#    )   

#model = xception_unet(
#    input_shape,
#    num_classes=y_train[0].shape[-1],
#    filters=NBFILTERS_L1_UNET, 
#    output_activation='softmax'
#    )

#model = attention_unet_smooth_network(
#    input_shape,
#    use_batch_norm=BATCHNORM_ON,  
#    upsample_mode='deconv',
#    num_classes=y_train[0].shape[-1],
#    filters=NBFILTERS_L1_UNET, 
#    dropout=DROPOUT_RATE,
#    num_layers=NBLAYERS_UNET,
#    output_activation='softmax',
#    kernel_regularizer=None # regularizers.l1(0.001)  # =None   for no regularization   
#    )
# Out:
#  input_shape :  (224, 224, 1)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  dropout (Dropout)              (None, 224, 224, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 32  9248        ['dropout[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 224, 224, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  dropout_1 (Dropout)            (None, 224, 224, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 112, 112, 32  0           ['dropout_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  dropout_2 (Dropout)            (None, 112, 112, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 64  36928       ['dropout_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  dropout_3 (Dropout)            (None, 112, 112, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['dropout_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  dropout_4 (Dropout)            (None, 56, 56, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 128)  147584      ['dropout_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  dropout_5 (Dropout)            (None, 56, 56, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0          ['dropout_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  dropout_6 (Dropout)            (None, 28, 28, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 256)  590080      ['dropout_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout_7 (Dropout)            (None, 28, 28, 256)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 256)  0          ['dropout_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  dropout_8 (Dropout)            (None, 14, 14, 512)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 14, 14, 512)  2359808     ['dropout_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 14, 14, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  dropout_9 (Dropout)            (None, 14, 14, 512)  0           ['batch_normalization_9[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)   0           ['dropout_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 1024)   4719616     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_10[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 7, 7, 1024)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 1024)   9438208     ['dropout_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_11[0][0]']
#  ormalization)
#
#  dropout_11 (Dropout)           (None, 7, 7, 1024)   0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 512)  2097664    ['dropout_11[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 14, 14, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'dropout_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 14, 14, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 14, 14, 512)  2359808     ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 256)  524544     ['batch_normalization_13[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 256)  590080      ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_15[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 56, 56, 128)  131200     ['batch_normalization_15[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 56, 56, 128)  295040      ['concatenate_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 56, 56, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  conv2d_17 (Conv2D)             (None, 56, 56, 128)  147584      ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 56, 56, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 112, 112, 64  32832      ['batch_normalization_17[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 112, 112, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'dropout_3[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 112, 112, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 112, 112, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  conv2d_19 (Conv2D)             (None, 112, 112, 64  36928       ['batch_normalization_18[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 112, 112, 64  256        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 224, 224, 32  8224       ['batch_normalization_19[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 224, 224, 64  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'dropout_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 224, 224, 32  18464       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 224, 224, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  conv2d_21 (Conv2D)             (None, 224, 224, 32  9248        ['batch_normalization_20[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 224, 224, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  conv2d_22 (Conv2D)             (None, 224, 224, 5)  165         ['batch_normalization_21[0][0]']
#
# ==================================================================================================
# Total params: 31,118,117
# Trainable params: 31,106,085
# Non-trainable params: 12,032
# __________________________________________________________________________________________________

# %% [markdown]
# ## <span style="color:brown"> 5.2- Compile the model
#
# ### Create callbacks for interactions during training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

print("model_filename : ", model_filename)

callback_checkpoint = ModelCheckpoint(
    model_filename, 
    verbose=1, 
    monitor='val_dice_coef', #'val_loss'
    mode ='max', # use 'min' or 'auto' if val_loss
    save_best_only=True
)

callback_earlystopping = EarlyStopping(
    monitor='val_dice_coef', #'val_loss'
    mode ='max', # use 'min' or 'auto' if val_loss
    patience=NBPATIENCE_EPOCHS,
    restore_best_weights=True  # at the end of fitting, restore best model weights 
)

logdir = "./logs/scalars/" + model_name + '_' + datetime.now().strftime("%Y-%m-%d_%Hh%M'")
print("logdir : ", logdir)
callback_tensorbooard = TensorBoard(
    log_dir=logdir, profile_batch=0
)
# Out:
# model_filename :  ./trained_model/Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN_input224.h5
# logdir :  ./logs/scalars/Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN_2023-05-20_13h40'

# %% [markdown]
# ### Compile the model
#
# i.e. : Set optimization algorithm, loss, metrics, ...

# %%
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras_unet.metrics import multi_dice_coef, dice_coef, iou, iou_thresholded
from keras_unet.losses import dice_loss, adaptive_loss
from tensorflow.keras.callbacks import TensorBoard

initial_learning_rate = 0.0005

# Optional scheduler to decrease learning rate according iterations or epoches
#lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#    initial_learning_rate,
#    decay_steps=10000,
#    decay_rate=0.96,
#    staircase=True)

cce_loss = tf.keras.losses.CategoricalCrossentropy(from_logits=False, label_smoothing=0.0)

model.compile(
    #loss=cce_loss,  # or 'categorical_crossentropy'
    loss=dice_loss,      # <- other loss you can test
    #loss=adaptive_loss,
    
    #optimizer=Adam(learning_rate=initial_learning_rate),  # 0.0001
    #optimizer=RMSprop(learning_rate=initial_learning_rate, rho=0.9, momentum=0.8, epsilon=1e-07, centered=True),  # <- other optimizer you can test
    optimizer=SGD(learning_rate=initial_learning_rate, momentum=0.99),  # 0.01 
      
    metrics=[dice_coef]
)

# %% [markdown]
# ## <span style="color:brown"> 5.3- Fit the model (train)
#
# Watch evolution of loss on epoches and time elapsed per epoch.
# If too long, you can stop the execution.

# %%
history = model.fit(
    X_train, y_train,  # use the 'original' images 
#    my_train_iter,           # use the images augmented by generator
#    steps_per_epoch=NBSTEPS_PER_EPOCH,  # uncomment when using 'myiter' (a data generator)
    batch_size=BATCH_SIZE,
    epochs=NBEPOCHS,
    validation_data=(X_val, y_val), 
    shuffle=True,
    verbose=1,
    callbacks=[callback_earlystopping, callback_checkpoint, callback_tensorbooard]
)
# Out:
# Epoch 1/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0336 - dice_coef: 0.7979
# Epoch 1: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 331ms/step - loss: 0.0336 - dice_coef: 0.7979 - val_loss: 0.0638 - val_dice_coef: 0.7083
# Epoch 2/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0333 - dice_coef: 0.8003
# Epoch 2: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 330ms/step - loss: 0.0333 - dice_coef: 0.8003 - val_loss: 0.0664 - val_dice_coef: 0.7067
# Epoch 3/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0330 - dice_coef: 0.8002
# Epoch 3: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 333ms/step - loss: 0.0330 - dice_coef: 0.8002 - val_loss: 0.0850 - val_dice_coef: 0.6904
# Epoch 4/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0331 - dice_coef: 0.8008
# Epoch 4: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 335ms/step - loss: 0.0331 - dice_coef: 0.8008 - val_loss: 0.0715 - val_dice_coef: 0.7044
# Epoch 5/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0331 - dice_coef: 0.8010
# Epoch 5: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 337ms/step - loss: 0.0331 - dice_coef: 0.8010 - val_loss: 0.0708 - val_dice_coef: 0.7146
# Epoch 6/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.8011
# Epoch 6: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 338ms/step - loss: 0.0328 - dice_coef: 0.8011 - val_loss: 0.0797 - val_dice_coef: 0.7161
# Epoch 7/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0331 - dice_coef: 0.8016
# Epoch 7: val_dice_coef did not improve from 0.71718
# 84/84 [==============================] - 28s 339ms/step - loss: 0.0331 - dice_coef: 0.8016 - val_loss: 0.0675 - val_dice_coef: 0.7139
# Epoch 8/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0330 - dice_coef: 0.8004
# Epoch 8: val_dice_coef improved from 0.71718 to 0.71931, saving model to ./trained_model/Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN_input224.h5
# 84/84 [==============================] - 30s 355ms/step - loss: 0.0330 - dice_coef: 0.8004 - val_loss: 0.0768 - val_dice_coef: 0.7193
# Epoch 9/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0332 - dice_coef: 0.8014
# Epoch 9: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0332 - dice_coef: 0.8014 - val_loss: 0.0667 - val_dice_coef: 0.7185
# Epoch 10/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.8030
# Epoch 10: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0328 - dice_coef: 0.8030 - val_loss: 0.0702 - val_dice_coef: 0.7102
# Epoch 11/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0329 - dice_coef: 0.8023
# Epoch 11: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 342ms/step - loss: 0.0329 - dice_coef: 0.8023 - val_loss: 0.0721 - val_dice_coef: 0.7070
# Epoch 12/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.8020
# Epoch 12: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 342ms/step - loss: 0.0328 - dice_coef: 0.8020 - val_loss: 0.0709 - val_dice_coef: 0.7042
# Epoch 13/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.8029
# Epoch 13: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0328 - dice_coef: 0.8029 - val_loss: 0.0768 - val_dice_coef: 0.7008
# Epoch 14/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0325 - dice_coef: 0.8046
# Epoch 14: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 345ms/step - loss: 0.0325 - dice_coef: 0.8046 - val_loss: 0.0673 - val_dice_coef: 0.7070
# Epoch 15/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0327 - dice_coef: 0.8045
# Epoch 15: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 344ms/step - loss: 0.0327 - dice_coef: 0.8045 - val_loss: 0.0685 - val_dice_coef: 0.7080
# Epoch 16/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0327 - dice_coef: 0.8045
# Epoch 16: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 344ms/step - loss: 0.0327 - dice_coef: 0.8045 - val_loss: 0.0657 - val_dice_coef: 0.7034
# Epoch 17/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0328 - dice_coef: 0.8039
# Epoch 17: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 344ms/step - loss: 0.0328 - dice_coef: 0.8039 - val_loss: 0.0682 - val_dice_coef: 0.7059
# Epoch 18/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0324 - dice_coef: 0.8050
# Epoch 18: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 350ms/step - loss: 0.0324 - dice_coef: 0.8050 - val_loss: 0.0641 - val_dice_coef: 0.7149
# Epoch 19/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0324 - dice_coef: 0.8063
# Epoch 22: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0324 - dice_coef: 0.8063 - val_loss: 0.0744 - val_dice_coef: 0.7011
# Epoch 23/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0324 - dice_coef: 0.8075
# Epoch 23: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 344ms/step - loss: 0.0324 - dice_coef: 0.8075 - val_loss: 0.0675 - val_dice_coef: 0.7076
# Epoch 24/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0322 - dice_coef: 0.8091
# Epoch 24: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0322 - dice_coef: 0.8091 - val_loss: 0.0662 - val_dice_coef: 0.7121
# Epoch 25/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0320 - dice_coef: 0.8098
# Epoch 25: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0320 - dice_coef: 0.8098 - val_loss: 0.0606 - val_dice_coef: 0.7175
# Epoch 26/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0321 - dice_coef: 0.8090
# Epoch 26: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0321 - dice_coef: 0.8090 - val_loss: 0.0674 - val_dice_coef: 0.7153
# Epoch 27/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0322 - dice_coef: 0.8087
# Epoch 27: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 345ms/step - loss: 0.0322 - dice_coef: 0.8087 - val_loss: 0.0678 - val_dice_coef: 0.7057
# Epoch 28/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0317 - dice_coef: 0.8096
# Epoch 28: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0317 - dice_coef: 0.8096 - val_loss: 0.0709 - val_dice_coef: 0.7095
# Epoch 29/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0320 - dice_coef: 0.8103
# Epoch 29: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0320 - dice_coef: 0.8103 - val_loss: 0.0627 - val_dice_coef: 0.7101
# Epoch 30/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0320 - dice_coef: 0.8095
# Epoch 30: val_dice_coef did not improve from 0.71931
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0320 - dice_coef: 0.8095 - val_loss: 0.0646 - val_dice_coef: 0.7180
# Epoch 31/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0318 - dice_coef: 0.8116
# Epoch 31: val_dice_coef improved from 0.71931 to 0.72342, saving model to ./trained_model/Unet_1i_f32_l5_k3_do0.1_actrelu_b16_Std_BN_input224.h5
# 84/84 [==============================] - 30s 359ms/step - loss: 0.0318 - dice_coef: 0.8116 - val_loss: 0.0620 - val_dice_coef: 0.7234
# Epoch 32/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0315 - dice_coef: 0.8118
# Epoch 32: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 342ms/step - loss: 0.0315 - dice_coef: 0.8118 - val_loss: 0.0737 - val_dice_coef: 0.7100
# Epoch 33/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0319 - dice_coef: 0.8102
# Epoch 33: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0319 - dice_coef: 0.8102 - val_loss: 0.0601 - val_dice_coef: 0.7184
# Epoch 34/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0320 - dice_coef: 0.8113
# Epoch 34: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0320 - dice_coef: 0.8113 - val_loss: 0.0740 - val_dice_coef: 0.7175
# Epoch 35/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0319 - dice_coef: 0.8111
# Epoch 35: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 342ms/step - loss: 0.0319 - dice_coef: 0.8111 - val_loss: 0.0630 - val_dice_coef: 0.7209
# Epoch 36/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0317 - dice_coef: 0.8112
# Epoch 36: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0317 - dice_coef: 0.8112 - val_loss: 0.0653 - val_dice_coef: 0.7160
# Epoch 37/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0314 - dice_coef: 0.8122
# Epoch 37: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0314 - dice_coef: 0.8122 - val_loss: 0.0614 - val_dice_coef: 0.7182
# Epoch 38/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0315 - dice_coef: 0.8127
# Epoch 38: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 28s 339ms/step - loss: 0.0315 - dice_coef: 0.8127 - val_loss: 0.0690 - val_dice_coef: 0.7049
# Epoch 39/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0316 - dice_coef: 0.8133
# Epoch 39: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0316 - dice_coef: 0.8133 - val_loss: 0.0751 - val_dice_coef: 0.6907
# Epoch 40/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0315 - dice_coef: 0.8133
# Epoch 40: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0315 - dice_coef: 0.8133 - val_loss: 0.0593 - val_dice_coef: 0.7093
# Epoch 41/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0313 - dice_coef: 0.8133
# Epoch 41: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0313 - dice_coef: 0.8133 - val_loss: 0.0656 - val_dice_coef: 0.6996
# Epoch 42/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8148
# Epoch 42: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 28s 339ms/step - loss: 0.0312 - dice_coef: 0.8148 - val_loss: 0.0654 - val_dice_coef: 0.7000
# Epoch 43/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8137
# Epoch 43: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0312 - dice_coef: 0.8137 - val_loss: 0.0765 - val_dice_coef: 0.6929
# Epoch 44/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8145
# Epoch 44: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 343ms/step - loss: 0.0312 - dice_coef: 0.8145 - val_loss: 0.0653 - val_dice_coef: 0.7097
# Epoch 45/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0313 - dice_coef: 0.8152
# Epoch 45: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 347ms/step - loss: 0.0313 - dice_coef: 0.8152 - val_loss: 0.0677 - val_dice_coef: 0.7025
# Epoch 46/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8155
# Epoch 46: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0312 - dice_coef: 0.8155 - val_loss: 0.0639 - val_dice_coef: 0.7084
# Epoch 47/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8152
# Epoch 47: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0312 - dice_coef: 0.8152 - val_loss: 0.0766 - val_dice_coef: 0.6969
# Epoch 48/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0312 - dice_coef: 0.8163
# Epoch 48: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 346ms/step - loss: 0.0312 - dice_coef: 0.8163 - val_loss: 0.0683 - val_dice_coef: 0.6992
# Epoch 49/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0310 - dice_coef: 0.8168
# Epoch 49: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0310 - dice_coef: 0.8168 - val_loss: 0.0663 - val_dice_coef: 0.7087
# Epoch 50/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0311 - dice_coef: 0.8161
# Epoch 50: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0311 - dice_coef: 0.8161 - val_loss: 0.0710 - val_dice_coef: 0.7097
# Epoch 51/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0309 - dice_coef: 0.8162
# Epoch 51: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0309 - dice_coef: 0.8162 - val_loss: 0.0663 - val_dice_coef: 0.7099
# Epoch 52/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0311 - dice_coef: 0.8166
# Epoch 52: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0311 - dice_coef: 0.8166 - val_loss: 0.0790 - val_dice_coef: 0.6905
# Epoch 53/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0313 - dice_coef: 0.8173
# Epoch 53: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0313 - dice_coef: 0.8173 - val_loss: 0.0754 - val_dice_coef: 0.6792
# Epoch 54/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0311 - dice_coef: 0.8167
# Epoch 54: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0311 - dice_coef: 0.8167 - val_loss: 0.0654 - val_dice_coef: 0.6928
# Epoch 55/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0309 - dice_coef: 0.8173
# Epoch 55: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0309 - dice_coef: 0.8173 - val_loss: 0.0684 - val_dice_coef: 0.6906
# Epoch 56/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0307 - dice_coef: 0.8192
# Epoch 56: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0307 - dice_coef: 0.8192 - val_loss: 0.0596 - val_dice_coef: 0.7093
# Epoch 57/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0307 - dice_coef: 0.8180
# Epoch 57: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0307 - dice_coef: 0.8180 - val_loss: 0.0621 - val_dice_coef: 0.7072
# Epoch 58/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0308 - dice_coef: 0.8188
# Epoch 58: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0308 - dice_coef: 0.8188 - val_loss: 0.0626 - val_dice_coef: 0.7183
# Epoch 59/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0307 - dice_coef: 0.8190
# Epoch 59: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 345ms/step - loss: 0.0307 - dice_coef: 0.8190 - val_loss: 0.0646 - val_dice_coef: 0.7157
# Epoch 60/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0307 - dice_coef: 0.8193
# Epoch 60: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 340ms/step - loss: 0.0307 - dice_coef: 0.8193 - val_loss: 0.0623 - val_dice_coef: 0.7158
# Epoch 61/500
# 84/84 [==============================] - ETA: 0s - loss: 0.0305 - dice_coef: 0.8188
# Epoch 61: val_dice_coef did not improve from 0.72342
# 84/84 [==============================] - 29s 341ms/step - loss: 0.0305 - dice_coef: 0.8188 - val_loss: 0.0650 - val_dice_coef: 0.7095

# %% [markdown]
# ## <span style="color:brown"> 5.4- Plot training and validation history

# %%
from keras_unet.visualization import plot_segm_history

plot_segm_history(history,  metrics=['dice_coef', 'val_dice_coef'])

# %% [markdown]
# ## <span style="color:brown"> 5.5- Plot training and validation during training with Tensorboard (NOT ON SATURN CLOUD)
#
# You can use tensorboard to watch loss and metric evolutions during training.
# To do so you can :
#   1. start a terminal in jupyter lab (File -> New launcher then 'Terminal'
#   2. in this terminal execute : ```$ tensorboard  --logdir ./logs/scalars/  ```

# %% [markdown]
# ## <span style="color:brown"> **6- Verify the model**

# %% [markdown]
# ## <span style="color:brown"> 6.1- Plot original + ground truth + pred + overlay (pred on top of original)

# %%
y_pred = model.predict(X_val, batch_size=1, verbose=1) # GPU Size 
loss, dice_coef = model.evaluate(x=X_val, y=y_val, batch_size=1, verbose=1) # 
print(f"loss : {loss}   Dice_coeff : {dice_coef}")

# %%
N_b = 0
N_e = 10
plot_compare_segmentation(X_val[N_b:N_e], y_val[N_b:N_e], y_pred[N_b:N_e], " ", spacing=(1,1), step=1)

# %% [markdown]
# ## <span style="color:red"> Questions
#
# - Run 20 more epoches and display curves and results again (... run the cells after §5.3). Are the results better ?
# - And 20 more ?
# - Train this network to have a DICE greater than 0.90.
# - Are the segmentation results convincing on the validation images ? Is this assessment correct?
# - Execute the next 2 cells : evaluation is performed on the test set ...

# %% [markdown]
# ## <span style="color:brown"> 6.2- Inference on test images

# %%
y_pred = model.predict(X_test, batch_size=1, verbose=1) # GPU Size
loss, dice_coef = model.evaluate(x=X_test, y=y_test, batch_size=1, verbose=1) # 
print(f"loss : {loss}   Dice_coeff : {dice_coef}")
# Out:
# 345/345 [==============================] - 4s 11ms/step
# 345/345 [==============================] - 4s 12ms/step - loss: 0.1255 - dice_coef: 0.7616
# loss : 0.1255253702402115   Dice_coeff : 0.7616094946861267

# %%
N_b = 114
N_e = 130
plot_compare_segmentation(X_test[N_b:N_e], y_test[N_b:N_e], y_pred[N_b:N_e], " ", spacing=(1,1), step=1)

# %% [markdown]
# ## <span style="color:red"> Questions
#
# - Optimize the training paramters to improve segmentation results (according the validation set iou thresholded value): regularizations, data sets size, hyper parameters (you can enable regularizations (drop out, Batch Norm, L1 or L2 on weights). Note that you can't check all configurations, so plan tests with your collegues ! (and have a look at AutoML)
#
# - Ok, the above training is long ;) So during training, display some information using Tensorboard: model shape and real time training curves.
#
# - What is early stopping and what it should avoid? Discuss the evolution of losses and metrcis during training.

# %% [markdown]
# ## <span style="color:brown"> **7- Accessing the learned filters**
#
# For understanding effect of layers, it can be of interest to display filters learned by the network.

# %%
print(" -> number of layers : ", len(model.layers) )
for a in range(1,len(model.layers)):
    print(f" index : {a}, layer name : {model.layers[a].name}")
# Out:
#  -> number of layers :  73
#  index : 1, layer name : conv2d_148
#  index : 2, layer name : batch_normalization
#  index : 3, layer name : dropout_104
#  index : 4, layer name : conv2d_149
#  index : 5, layer name : batch_normalization_1
#  index : 6, layer name : dropout_105
#  index : 7, layer name : max_pooling2d_44
#  index : 8, layer name : conv2d_150
#  index : 9, layer name : batch_normalization_2
#  index : 10, layer name : dropout_106
#  index : 11, layer name : conv2d_151
#  index : 12, layer name : batch_normalization_3
#  index : 13, layer name : dropout_107
#  index : 14, layer name : max_pooling2d_45
#  index : 15, layer name : conv2d_152
#  index : 16, layer name : batch_normalization_4
#  index : 17, layer name : dropout_108
#  index : 18, layer name : conv2d_153
#  index : 19, layer name : batch_normalization_5
#  index : 20, layer name : dropout_109
#  index : 21, layer name : max_pooling2d_46
#  index : 22, layer name : conv2d_154
#  index : 23, layer name : batch_normalization_6
#  index : 24, layer name : dropout_110
#  index : 25, layer name : conv2d_155
#  index : 26, layer name : batch_normalization_7
#  index : 27, layer name : dropout_111
#  index : 28, layer name : max_pooling2d_47
#  index : 29, layer name : conv2d_156
#  index : 30, layer name : batch_normalization_8
#  index : 31, layer name : dropout_112
#  index : 32, layer name : conv2d_157
#  index : 33, layer name : batch_normalization_9
#  index : 34, layer name : dropout_113
#  index : 35, layer name : max_pooling2d_48
#  index : 36, layer name : conv2d_158
#  index : 37, layer name : batch_normalization_10
#  index : 38, layer name : dropout_114
#  index : 39, layer name : conv2d_159
#  index : 40, layer name : batch_normalization_11
#  index : 41, layer name : dropout_115
#  index : 42, layer name : conv2d_transpose_24
#  index : 43, layer name : concatenate_24
#  index : 44, layer name : conv2d_160
#  index : 45, layer name : batch_normalization_12
#  index : 46, layer name : conv2d_161
#  index : 47, layer name : batch_normalization_13
#  index : 48, layer name : conv2d_transpose_25
#  index : 49, layer name : concatenate_25
#  index : 50, layer name : conv2d_162
#  index : 51, layer name : batch_normalization_14
#  index : 52, layer name : conv2d_163
#  index : 53, layer name : batch_normalization_15
#  index : 54, layer name : conv2d_transpose_26
#  index : 55, layer name : concatenate_26
#  index : 56, layer name : conv2d_164
#  index : 57, layer name : batch_normalization_16
#  index : 58, layer name : conv2d_165
#  index : 59, layer name : batch_normalization_17
#  index : 60, layer name : conv2d_transpose_27
#  index : 61, layer name : concatenate_27
#  index : 62, layer name : conv2d_166
#  index : 63, layer name : batch_normalization_18
#  index : 64, layer name : conv2d_167
#  index : 65, layer name : batch_normalization_19
#  index : 66, layer name : conv2d_transpose_28
#  index : 67, layer name : concatenate_28
#  index : 68, layer name : conv2d_168
#  index : 69, layer name : batch_normalization_20
#  index : 70, layer name : conv2d_169
#  index : 71, layer name : batch_normalization_21
#  index : 72, layer name : conv2d_170

# %%
N_l = 1 # Remember that some layers have no weights !
print("-> Get config : ", model.layers[N_l].get_config())  # get whole information of the layer (config of the layer)
# Out:
# -> Get config :  {'name': 'conv2d_148', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'HeNormal', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}

# %%
print("-> Get shape : ", model.layers[N_l].get_weights()[0].shape) #ok this line works only if some weights exist (X,Y,C,Neurons)
w = model.layers[N_l].get_weights()[0][:,:,0,:]
print(w.shape[2])
# Out:
# -> Get shape :  (3, 3, 1, 16)
# 16

# %%
nb_filters = w.shape[2]
nb_filters_per_line = 8   # 
if nb_filters > 256: nb_filters = 256
if nb_filters < 9: nb_filters_per_line = nb_filters
#assert nb_filters < 256
plt.subplots(nb_filters//nb_filters_per_line,nb_filters_per_line,figsize=(20,5))
for i in range(1,nb_filters+1,1):  
    plt.subplot(nb_filters//nb_filters_per_line,nb_filters_per_line,i) # current plot is i
    plt.imshow(w[:,:,i-1], interpolation='none', cmap='gray')
    plt.axis('off')

# %% [markdown]
# ## <span style="color:red"> Question
#
# - Visualize and discuss the filters of the first CNN after the first maxpooling (conv2d_3 layer). Justify its shape.

# %% [markdown]
# ## <span style="color:brown"> **8- Observing the intermediate images**
#
# Intermediate images are images at the output of layers.
# This task can be done efficiently using a second network that just copies all outputs of our network (the variable is *model*) to allow us displaying the activations.

# %%
layer_outputs = [layer.output for layer in model.layers[1:]]  # skip input for fed problem
print( len(layer_outputs) )
# Extracts the outputs 
activation_model  = models.Model(inputs=model.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input
# Out:
# 72

# %% [markdown]
# Here we select an image (in the validation set... it can be changed!)

# %%
Index_img_to_display = 9
print(X_val_e8[Index_img_to_display:Index_img_to_display+1,:,:,:].shape)
activations = activation_model.predict(X_val_e8[Index_img_to_display:Index_img_to_display+1,:,:,:])
# Out:
# (1, 96, 96, 1)
# 1/1 [==============================] - 1s 533ms/step

# %% [markdown]
# Here we select an activation output. For convenience, indexes of layers have been preserved from 0 to N (0 means input and is not mapped to this model)

# %%
Index_Output_Layer = 1 #N_l
first_layer_activation = activations[Index_Output_Layer - 1]
print(first_layer_activation.shape)
# Out:
# (1, 96, 96, 16)

# %%
#plt.figure(figsize=(10,10))
#plt.imshow(first_layer_activation[0, :, :, 2], cmap='viridis')  

nb_filters =first_layer_activation.shape[3]
nb_filters_per_line = 8   # 
if nb_filters > 256: nb_filters = 256
if nb_filters < 9: nb_filters_per_line = nb_filters
#assert nb_filters < 256
plt.subplots(nb_filters//nb_filters_per_line,nb_filters_per_line,figsize=(20,5))
for i in range(1,nb_filters+1,1):  
    plt.subplot(nb_filters//nb_filters_per_line,nb_filters_per_line,i) # current plot is i
    plt.imshow(first_layer_activation[0, :, :, i-1], interpolation='bilinear', cmap='viridis' )#, vmin=0, vmax=1)
    plt.axis('off')

# %% [markdown]
# ## <span style="color:red"> Questions
#
# - Visualize and discuss the filters conv2d_3 layer (the first CNN after the first maxpooling). Justify its shape.
# - Visualize and discuss the last filter.

# %% [markdown]
# ## <span style="color:red"> Questions, to finish ...
#
# - Modify the network to use the 3 MRI sequences as input (e8, e5 and e2). Follow the training with tensorboard. Is DICE improved?
#
# - Modify the code to use the Xception_unet with ADAM optimizer. First change the __model_filename__ string to facilitate comparisons with previous training.
#
# - How much time to manual segment an image ? Why it is critical to have good (expert, consistent) annotated images? With no more new data, what can be done to __augment__ our train data set?

# %% [markdown]
# ## <span style="color:brown"> **Following cells are some help and information**

# %% [markdown]
# ### <span style="color:brown"> Tensorboard (reminder)
#
# Tensorboard allows many training, graph, images supervision using a simple web navigator: you just have to connect to the server.
# Many ways to use it whitin jupyter notebook or not.
#
# The easyest way is to launch tensorboard in the command line (stand alone program)
# ``` bash
# tensorboard --logdir ./logs/scalars/  --bind_all
# ```
# Adapt the logdir directory to point out desired files (this exmple work with this notebook)
# With the __bind_all__ option, all internet interfaces will expose the tensorboard server.
# Then, you can connect with 127.0.0.1:6006 or other interfaces which are listed when tensorboard started
# (the port number can be changed with --port option, --host can be used to specify a dedicated IP for the server).
#
# It is also possible to incoporate tensorboard directly in jupyter-lab using an extension or using it as a cell.
#
# - As cell (using magics): https://www.tensorflow.org/tensorboard/tensorboard_in_notebooks
# - As extension (require dedicated installation) : https://github.com/chaoleili/jupyterlab_tensorboard   or https://github.com/HFAiLab/jupyterlab_tensorboard_pro

# %% [markdown]
# ### <span style="color:brown"> Hints for usage of 3 MRI as input
#
# - **first**, the input image shape has now 3 channels:
# ``` python
# input_shape = (IMG_SIZE, IMG_SIZE, 3) # see the "3" instead of 1
# ```
#
# - **second** we need to build the input tensor by concatenating the three MRI:
# ``` python
# concat_train = tf.keras.layers.Concatenate()([X_train_e8, X_train_e5, X_train_e2])
# concat_val = tf.keras.layers.Concatenate()([X_val_e8, X_val_e5, X_val_e2])
# print(concat_train.shape)
# plt.imshow(concat_train[0]) # display in color :p
# ```
#
# - **third**, train the model. Note that it not necessary to modify the architectucture as only the input shape evolve (and thus only the number of parameters of the first layer)
# ``` python
# history = model.fit(
#     concat_train, y_train,
#     batch_size=BATCH_SIZE,
#     epochs=NBEPOCHS,
#     validation_data=(concat_val, y_val),
#     shuffle=True,
#     verbose=1,
#     callbacks=[ callback_earlystopping, callback_checkpoint, callback_tensorbooard]
# )
# ```
# - **fourth**, remind to adapt the prediction on the concatenated tensors!
# ``` python
# y_pred = model.predict(concat_val, batch_size=1, verbose=1) # GPU Size
# loss, dice_coef = model.evaluate(x=concat_val, y=y_val, batch_size=1, verbose=1) #
# print(f"loss : {loss}   Dice_coeff : {dice_coef}")
# print(y_pred.shape)
# ```
